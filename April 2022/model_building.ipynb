# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
scan_1 = pd.read_csv("nap-scan.csv")
scan_2 = pd.read_csv("nap-scan-2.csv")
cols = ["ApId",
"NApMacAddress",
"LastCheckinTime",
"LastStatusId",         
"SSID",                 
"TSF",                  
"Frequency",            
"Rssi",                  
"PrimaryChannel",       
"SecondaryChannel",     
"ChannelWidth",         
"StaChannelWidth",      
"FirstCenterFrequency", 
"SecondCenterFrequency",
"Authentication",       
"Security"]
scan_1.columns = cols
# checking the column 
print(scan_2[r'\N'].value_counts(), len(scan_2[r'\N']))
# seems like the \N col is having only newline values dropping it 
scan_2 = scan_2.drop(r"\N", axis = 1 ) 
scan_2.columns = cols
total_scan = scan_1.append(scan_2, ignore_index=True)
# Out:
# \N    5259
# Name: \N, dtype: int64 5259
# /tmp/ipykernel_12851/3795742374.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_scan = scan_1.append(scan_2, ignore_index=True)

# %%
total_scan
# Out:
#       ApId      NApMacAddress      LastCheckinTime  LastStatusId  \
# 0      297  EA:48:B8:C2:6F:BC  2022-04-05 04:46:18       1275036
# 1      320  04:95:E6:9E:80:78  2022-04-07 10:12:19       1298899
# 2      320  04:95:E6:A6:50:90  2022-04-07 10:12:19       1298899
# 3      320  32:84:2F:EB:A5:40  2022-04-07 10:12:19       1298899
# 4      320  34:CE:00:23:5D:00  2022-04-07 10:12:19       1298899
# ...    ...                ...                  ...           ...
# 6198  2187  72:6D:EC:0A:4C:23  2022-04-11 11:39:33      15711825
# 6199  2187  72:6D:EC:0A:83:33  2022-04-11 11:39:33      15711825
# 6200  2187  72:6D:EC:0A:8A:17  2022-04-11 11:39:33      15711825
# 6201  2187  76:6D:EC:0A:4C:23  2022-04-11 11:39:33      15711825
# 6202  2187  E8:6F:38:29:FD:E9  2022-04-11 11:39:33      15711825
#
#                               SSID            TSF  Frequency  Rssi  \
# 0                    x20Free_Wi-Fi     3806851836         11   -59
# 1                            L.S.C    43136848531         10   -72
# 2                           Singla    45709517200          2   -83
# 3                         Redmi 9A  1276727306001         11   -85
# 4                      Xiaomi_5CFF    12711629212          1   -84
# ...                            ...            ...        ...   ...
# 6198                           NaN   369069911408        153   -55
# 6199           INDIO-cast-failover   525933864222        149   -51
# 6200           INDIO-cast-failover  5466269661876         52   -49
# 6201                           NaN   369069945541        153   -55
# 6202  HP-Print-E9-LaserJet Pro MFP   605006027586          6   -54
#
#       PrimaryChannel  SecondaryChannel  ChannelWidth StaChannelWidth  \
# 0                 11                 0           NaN              20
# 1                 10                 0           NaN              20
# 2                  2                 0           NaN             any
# 3                 11                 0           0.0              20
# 4                  1                 0           NaN              20
# ...              ...               ...           ...             ...
# 6198             127                 0           0.0              20
# 6199             127                 0           1.0             any
# 6200              52                 0           1.0             any
# 6201             127                 0           0.0              20
# 6202               6                 0           NaN              20
#
#       FirstCenterFrequency  SecondCenterFrequency Authentication   Security
# 0                      NaN                    NaN            NaN        NaN
# 1                      NaN                    NaN            PSK       CCMP
# 2                      NaN                    NaN            PSK       CCMP
# 3                      0.0                    0.0            PSK       CCMP
# 4                      NaN                    NaN            PSK  TKIP CCMP
# ...                    ...                    ...            ...        ...
# 6198                 153.0                    0.0            PSK  CCMP TKIP
# 6199                 155.0                    0.0            PSK  CCMP TKIP
# 6200                  58.0                    0.0            PSK  CCMP TKIP
# 6201                 153.0                    0.0            PSK  CCMP TKIP
# 6202                   NaN                    NaN            NaN        NaN
#
# [6203 rows x 16 columns]

# %%
total_scan.isna().sum()
# Out:
# ApId                        0
# NApMacAddress               0
# LastCheckinTime             0
# LastStatusId                0
# SSID                      330
# TSF                         0
# Frequency                   0
# Rssi                        0
# PrimaryChannel              0
# SecondaryChannel            0
# ChannelWidth             4998
# StaChannelWidth           185
# FirstCenterFrequency     4998
# SecondCenterFrequency    4998
# Authentication           1774
# Security                 1774
# dtype: int64

# %%
cont_features = ["Rssi","ChannelWidth",]# StaChannelWidth,FirstCenterFrequency
to_predict = ["PrimaryChannel"]

# %%
total_scan.PrimaryChannel.value_counts()
# Out:
# 11     1604
# 1      1545
# 6       735
# 127     488
# 10      218
# 0       185
# 9       156
# 36      154
# 2       131
# 52      131
# 8       127
# 7       110
# 4       103
# 3        98
# 5        83
# 13       73
# 40       69
# 44       65
# 48       34
# 60       24
# 64       18
# 116      11
# 12       11
# 100      10
# 56        9
# 108       9
# 104       1
# 124       1
# Name: PrimaryChannel, dtype: int64

# %%
total_scan.dtypes
# Out:
# ApId                       int64
# NApMacAddress             object
# LastCheckinTime           object
# LastStatusId               int64
# SSID                      object
# TSF                        int64
# Frequency                  int64
# Rssi                       int64
# PrimaryChannel             int64
# SecondaryChannel           int64
# ChannelWidth             float64
# StaChannelWidth           object
# FirstCenterFrequency     float64
# SecondCenterFrequency    float64
# Authentication            object
# Security                  object
# dtype: object

# %%
from pycaret.classification import *

# creaing setup 
expt = setup(total_scan,target="PrimaryChannel",numeric_features =cont_features, preprocess = True ,  normalize = True , silent = True, 
use_gpu=True 
)
# Out:
# <style type="text/css">
# #T_e0203_row5_col1, #T_e0203_row18_col1, #T_e0203_row29_col1, #T_e0203_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e0203">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0203_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e0203_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0203_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0203_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e0203_row0_col1" class="data row0 col1" >2704</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0203_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e0203_row1_col1" class="data row1 col1" >PrimaryChannel</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0203_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_e0203_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0203_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_e0203_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0203_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_e0203_row4_col1" class="data row4 col1" >(6203, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0203_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_e0203_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0203_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_e0203_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0203_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_e0203_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0203_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_e0203_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0203_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_e0203_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e0203_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_e0203_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e0203_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_e0203_row11_col1" class="data row11 col1" >(4342, 2349)</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e0203_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_e0203_row12_col1" class="data row12 col1" >(1861, 2349)</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e0203_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_e0203_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e0203_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_e0203_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e0203_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e0203_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e0203_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e0203_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e0203_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e0203_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e0203_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e0203_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e0203_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e0203_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e0203_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e0203_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e0203_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e0203_row21_col1" class="data row21 col1" >f7e7</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e0203_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_e0203_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e0203_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e0203_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e0203_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_e0203_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e0203_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e0203_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e0203_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_e0203_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e0203_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e0203_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e0203_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e0203_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e0203_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_e0203_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e0203_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e0203_row30_col0" class="data row30 col0" >Normaliz

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_62a0e th {
#   text-align: left;
# }
# #T_62a0e_row0_col0, #T_62a0e_row1_col0, #T_62a0e_row1_col1, #T_62a0e_row1_col3, #T_62a0e_row1_col4, #T_62a0e_row1_col5, #T_62a0e_row1_col6, #T_62a0e_row1_col7, #T_62a0e_row2_col0, #T_62a0e_row2_col1, #T_62a0e_row2_col3, #T_62a0e_row2_col4, #T_62a0e_row2_col5, #T_62a0e_row2_col6, #T_62a0e_row2_col7, #T_62a0e_row3_col0, #T_62a0e_row3_col1, #T_62a0e_row3_col3, #T_62a0e_row3_col4, #T_62a0e_row3_col5, #T_62a0e_row3_col6, #T_62a0e_row3_col7, #T_62a0e_row4_col0, #T_62a0e_row4_col1, #T_62a0e_row4_col3, #T_62a0e_row4_col4, #T_62a0e_row4_col5, #T_62a0e_row4_col6, #T_62a0e_row4_col7, #T_62a0e_row5_col0, #T_62a0e_row5_col1, #T_62a0e_row5_col3, #T_62a0e_row5_col4, #T_62a0e_row5_col5, #T_62a0e_row5_col6, #T_62a0e_row5_col7, #T_62a0e_row6_col0, #T_62a0e_row6_col1, #T_62a0e_row6_col3, #T_62a0e_row6_col4, #T_62a0e_row6_col5, #T_62a0e_row6_col6, #T_62a0e_row6_col7, #T_62a0e_row7_col0, #T_62a0e_row7_col1, #T_62a0e_row7_col3, #T_62a0e_row7_col4, #T_62a0e_row7_col5, #T_62a0e_row7_col6, #T_62a0e_row7_col7, #T_62a0e_row8_col0, #T_62a0e_row8_col1, #T_62a0e_row8_col3, #T_62a0e_row8_col4, #T_62a0e_row8_col5, #T_62a0e_row8_col6, #T_62a0e_row8_col7, #T_62a0e_row9_col0, #T_62a0e_row9_col1, #T_62a0e_row9_col3, #T_62a0e_row9_col4, #T_62a0e_row9_col5, #T_62a0e_row9_col6, #T_62a0e_row9_col7, #T_62a0e_row10_col0, #T_62a0e_row10_col1, #T_62a0e_row10_col3, #T_62a0e_row10_col4, #T_62a0e_row10_col5, #T_62a0e_row10_col6, #T_62a0e_row10_col7, #T_62a0e_row11_col0, #T_62a0e_row11_col1, #T_62a0e_row11_col3, #T_62a0e_row11_col4, #T_62a0e_row11_col5, #T_62a0e_row11_col6, #T_62a0e_row11_col7, #T_62a0e_row12_col0, #T_62a0e_row12_col1, #T_62a0e_row12_col3, #T_62a0e_row12_col4, #T_62a0e_row12_col5, #T_62a0e_row12_col6, #T_62a0e_row12_col7, #T_62a0e_row13_col0, #T_62a0e_row13_col1, #T_62a0e_row13_col3, #T_62a0e_row13_col4, #T_62a0e_row13_col5, #T_62a0e_row13_col6, #T_62a0e_row13_col7 {
#   text-align: left;
# }
# #T_62a0e_row0_col1, #T_62a0e_row0_col2, #T_62a0e_row0_col3, #T_62a0e_row0_col4, #T_62a0e_row0_col5, #T_62a0e_row0_col6, #T_62a0e_row0_col7, #T_62a0e_row1_col2, #T_62a0e_row2_col2, #T_62a0e_row3_col2, #T_62a0e_row4_col2, #T_62a0e_row5_col2, #T_62a0e_row6_col2, #T_62a0e_row7_col2, #T_62a0e_row8_col2, #T_62a0e_row9_col2, #T_62a0e_row10_col2, #T_62a0e_row11_col2, #T_62a0e_row12_col2, #T_62a0e_row13_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T
_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_62a0e_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_62a0e_row5_col1" class="data row5 col1" >0.8441</td>
#       <td id="T_62a0e_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_62a0e_row5_col3" class="data row5 col3" >0.6518</td>
#       <td id="T_62a0e_row5_col4" class="data row5 col4" >0.8364</td>
#       <td id="T_62a0e_row5_col5" class="data row5 col5" >0.8326</td>
#       <td id="T_62a0e_row5_col6" class="data row5 col6" >0.8137</td>
#       <td id="T_62a0e_row5_col7" class="data row5 col7" >0.8147</td>
#       <td id="T_62a0

# %%
model = create_model(best)
# Out:
# <style type="text/css">
# #T_961e1_row10_col0, #T_961e1_row10_col1, #T_961e1_row10_col2, #T_961e1_row10_col3, #T_961e1_row10_col4, #T_961e1_row10_col5, #T_961e1_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_961e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_961e1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_961e1_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_961e1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_961e1_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_961e1_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_961e1_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_961e1_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_961e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_961e1_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_961e1_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_961e1_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_961e1_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_961e1_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_961e1_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_961e1_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_961e1_row1_col0" class="data row1 col0" >0.9977</td>
#       <td id="T_961e1_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_961e1_row1_col2" class="data row1 col2" >0.9600</td>
#       <td id="T_961e1_row1_col3" class="data row1 col3" >0.9955</td>
#       <td id="T_961e1_row1_col4" class="data row1 col4" >0.9966</td>
#       <td id="T_961e1_row1_col5" class="data row1 col5" >0.9973</td>
#       <td id="T_961e1_row1_col6" class="data row1 col6" >0.9973</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_961e1_row2_col0" class="data row2 col0" >0.9954</td>
#       <td id="T_961e1_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_961e1_row2_col2" class="data row2 col2" >0.9933</td>
#       <td id="T_961e1_row2_col3" class="data row2 col3" >0.9961</td>
#       <td id="T_961e1_row2_col4" class="data row2 col4" >0.9954</td>
#       <td id="T_961e1_row2_col5" class="data row2 col5" >0.9946</td>
#       <td id="T_961e1_row2_col6" class="data row2 col6" >0.9946</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_961e1_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_961e1_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_961e1_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_961e1_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_961e1_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_961e1_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_961e1_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_961e1_row4_col0" class="data row4 col0" >0.9977</td>
#       <td id="T_961e1_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_961e1_row4_col2" class="data row4 col2" >0.9965</td>
#       <td id="T_961e1_row4_col3" class="data row4 col3" >0.9979</td>
#       <td id="T_961e1_row4_col4" class="data row4 col4" >0.9977</td>
#       <td id="T_961e1_row4_col5" class="data row4 col5" >0.9973</td>
#       <td id="T_961e1_row4_col6" class="data row4 col6" >0.9973</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_961e1_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_961e1_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_961e1_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_961e1_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_961e1_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_961e1_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_961e1_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_961e1_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_961e1_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_961e1_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_961e1_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_961e1_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_961e1_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_961e1_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_961e1_row7_col0" class="data row7 col0" >0.9954</td>
#       <td id="T_961e1_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_961e1_row7_col2" class="data row7 col2" >0.9200</td>
#       <td id="T_961e1_row7_col3" class="data row7 col3" >0.9939</td>
#       <td id="T_961e1_row7_col4" class="data row7 col4" >0.9942</td>
#       <td id="T_961e1_row7_col5" class="data row7 col5" >0.9946</td>
#       <td id="T_961e1_row7_col6" class="data row7 col6" >0.9946</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_961e1_row8_col0" class="data row8 col0" >0.9977</td>
#       <td id="T_961e1_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_961e1_row8_col2" class="data row8 col2" >0.9965</td>
#       <td id="T_961e1_row8_col3" class="data row8 col3" >0.9979</td>
#       <td id="T_961e1_row8_col4" class="data row8 col4" >0.9977</td>
#       <td id="T_961e1_row8_col5" class="data row8 col5" >0.9973</td>
#       <td id="T_961e1_row8_col6" class="data row8 col6" >0.9973</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_961e1_row9_col0" class="data row9 col0" >0.9954</td>
#       <td id="T_961e1_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_961e1_row9_col2" class="data row9 col2" >0.9936</td>
#       <td id="T_961e1_row9_col3" class="data row9 col3" >0.9961</td>
#       <td id="T_961e1_row9_col4" class="data row9 col4" >0.9954</td>
#       <td id="T_961e1_row9_col5" class="data row9 col5" >0.9946</td>
#       <td id="T_961e1_row9_col6" class="data row9 col6" >0.9946</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_961e1_row10_col0" class="data row10 col0" >0.9979</td>
#       <td id="T_961e1_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_961e1_row10_col2" class="data row10 col2" >0.9860</td>
#       <td id="T_961e1_row10_col3" class="data row10 col3" >0.9977</td>
#       <td id="T_961e1_row10_col4" class="data row10 col4" >0.9977</td>
#       <td id="T_961e1_row10_col5" class="data row10 col5" >0.9976</td>
#       <td id="T_961e1_row10_col6" class="data row10 col6" >0.9976</td>
#     </tr>
#     <tr>
#       <th id="T_961e1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_961e1_row11_col0" class="data row11 col0" >0.0019</td>
#       <td id="T_961e1_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_961e1_row11_col2" class="data row11 col2" >0.0248</td>
#       <td id="T_961e1_row11_col3" class="data row11 col3" >0.0021</td>
#       <td id="T_961e1_row11_col4

# %%
# saving compared models 
save_model(best, "compare_model_res")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['Rssi',
#                                                            'ChannelWidth'],
#                                        target='PrimaryChannel',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_valu...
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          presort='deprecated', random_state=2704,
#                                          splitter='best')]],
#           verbose=False),
#  'compare_model_res.pkl')

# %%
save_model(model , "dt")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['Rssi',
#                                                            'ChannelWidth'],
#                                        target='PrimaryChannel',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_valu...
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          presort='deprecated', random_state=2704,
#                                          splitter='best')]],
#           verbose=False),
#  'dt.pkl')

# %%
def create_graph(node, df):
    node_data = df.query(f"ApId == {node}")
    print(node_data)

# %%
total_scan.query("ApId == 297")
# Out:
#    ApId      NApMacAddress      LastCheckinTime  LastStatusId           SSID  \
# 0   297  EA:48:B8:C2:6F:BC  2022-04-05 04:46:18       1275036  x20Free_Wi-Fi
#
#           TSF  Frequency  Rssi  PrimaryChannel  SecondaryChannel  \
# 0  3806851836         11   -59              11                 0
#
#    ChannelWidth StaChannelWidth  FirstCenterFrequency  SecondCenterFrequency  \
# 0           NaN              20                   NaN                    NaN
#
#   Authentication Security
# 0            NaN      NaN

# %%
total_scan.ApId.value_counts()
# Out:
# 678     71
# 719     63
# 967     51
# 2138    48
# 1565    47
#         ..
# 1397     1
# 1444     1
# 1454     1
# 864      1
# 297      1
# Name: ApId, Length: 422, dtype: int64

# %%
create_graph(1565, total_scan)
# Out:
#       ApId      NApMacAddress      LastCheckinTime  LastStatusId  \
# 3751  1565  00:95:69:E0:41:D2  2022-04-09 04:22:33      15587861
# 3752  1565  00:A0:0A:24:1F:D0  2022-04-09 04:22:33      15587861
# 3753  1565  00:A0:0A:27:52:50  2022-04-09 04:22:33      15587861
# 3754  1565  00:A0:0A:2A:72:C0  2022-04-09 04:22:33      15587861
# 3755  1565  0C:D2:B5:4B:B0:42  2022-04-09 04:22:33      15587861
# 3756  1565  20:DB:AB:37:8D:80  2022-04-09 04:22:33      15587861
# 3795  1565  70:6D:EC:0A:83:B8  2022-04-09 04:22:33      15587861
# 3796  1565  70:6D:EC:0A:85:10  2022-04-09 04:22:33      15587861
# 3797  1565  74:DA:DA:B9:0D:9E  2022-04-09 04:22:33      15587861
#
#                    SSID            TSF  Frequency  Rssi  PrimaryChannel  \
# 3751         Cos-Link00   737778483570         11   -85              11
# 3752      JioPrivateNet        6264977          1   -82               1
# 3753      JioPrivateNet         390969         11   -83              11
# 3754      JioPrivateNet  1780665447459        157   -86             127
# 3755       SAYAJI HOTEL     1049104188         11   -53              11
# 3756             JioNet  4607504811884         60   -68              60
# 3757      JioPrivateNet  4607504761241         60   -67              60
# 3758             JioNet  4607508903245         48   -68              48
# 3759      JioPrivateNet  4607508853354         48   -67              48
# 3760      JioPrivateNet  4607490286261          6   -61               6
# 3761             JioNet  4607490157049          6   -65               6
# 3762             JioNet  4607159098140         52   -67              52
# 3763      JioPrivateNet  4607159047478         52   -66              52
# 3764      JioPrivateNet  4607146991074          6   -71               6
# 3765             JioNet  4607147075276          6   -79               6
# 3766             JioNet  4607477983139        165   -76             127
# 3767      JioPrivateNet  4607477932482        165   -76             127
# 3768      JioPrivateNet  4607468187866         11   -45              11
# 3769             JioNet  4607468170247         11   -52              11
# 3770             JioNet  4607548891195        149   -89             127
# 3771             JioNet  4607526960352         44   -85              44
# 3772      JioPrivateNet  4607526909694         44   -84              44
# 3773      JioPrivateNet  4607494517120          6   -81               6
# 3774             JioNet  4607494619520          6   -77               6
# 3775             JioNet  4607503184465        149   -85             127
# 3776             JioNet  4607555241840         36   -49              36
# 3777      JioPrivateNet  4607555191258         36   -51              36
# 3778      JioPrivateNet  4607509239270         11   -55              11
# 3779             JioNet  4607509256928         11   -57              11
# 3780             JioNet  4607505682760        157   -81             127
# 3781      JioPrivateNet  4607505632093        157   -82             127
# 3782      JioPrivateNet  4607504362112          1   -76               1
# 3783             JioNet  4607504491523          1   -76               1
# 3784      JioPrivateNet    28895683362         11   -76              11
# 3785             JioNet    28895715479         11   -75              11
# 3786             JioNet    28896863963        157   -74             127
# 3787      JioPrivateNet    28896813300        157   -75             127
# 3788      JioPrivateNet    28888451822         11   -58              11
# 3789             JioNet    28888480003         11   -58              11
# 3790      JioPrivateNet  4607529945651          6   -68               6
# 3791             JioNet  4607529831237          6   -80               6
# 3792       Hasan....10S     3484402689         11   -50              11
# 3793       SAYAJI HOTEL      232709659          1   -66               1
# 3794       SAYAJI HOTEL    52494745984          1   -92               1
# 3795       SAYAJI HOTEL    52495159732          1   -67               1
# 3796              admin     2135961984          1   -56               1
# 3797  Airtel_7389933182      238182809          8   -84               8
#
#       SecondaryChannel  ChannelWidth StaChannelWidth  FirstCenterFrequency  \
# 3751                 0           NaN              20                   NaN
# 3752                 0           NaN              20                   NaN
# 3753                 0           NaN              20                   NaN
# 3754                 0           0.0             any                   0.0
# 3755                 0           NaN             any                   NaN
# 3756                 0           0.0             any                   0.0
# 3757                 0           0.0             any                   0.0
# 3758                 0           0.0             any                   0.0
# 3759                 0           0.0             any                   0.0
# 3760                 0           NaN              20                   NaN
# 3761                 0           NaN              20                   NaN
# 3762                 0           0.0             any                   0.0
# 3763                 0           0.0             any                   0.0
# 3764                 0           NaN              20                   NaN
# 3765                 0           NaN              20                   NaN
# 3766                 0           0.0             any                   0.0
# 3767                 0           0.0             any                   0.0
# 3768                 0           NaN              20                   NaN
# 3769                 0           NaN              20                   NaN
# 3770                 0           0.0             any                   0.0
# 3771                 0           0.0             any                   0.0
# 3772                 0           0.0             any                   0.0
# 3773                 0           NaN              20                   NaN
# 3774                 0           NaN              20                   NaN
# 3775                 0           0.0             any                   0.0
# 3776                 0           0.0             any                   0.0
# 3777                 0           0.0             any                   0.0
# 3778                 0           NaN              20                   NaN
# 3779                 0           NaN              20                   NaN
# 3780                 0           0.0             any                   0.0
# 3781                 0           0.0             any                   0.0
# 3782                 0           NaN              20                   NaN
# 3783                 0           NaN              20                   NaN
# 3784                 0           NaN              20                   NaN
# 3785                 0           NaN              20                   NaN
# 3786                 0           0.0             any                   0.0
# 3787                 0           0.0             any                   0.0
# 3788                 0           NaN              20                   NaN
# 3789                 0           NaN              20                   NaN
# 3790                 0           NaN              20                   NaN
# 3791                 0           NaN              20                   NaN
# 3792                 0           0.0              20                   0.0
# 3793                 0           NaN              20                   NaN
# 3794                 0           NaN              20                   NaN
# 3795                 0           NaN              20                   NaN
# 3796                 0           NaN              20                   NaN
# 3797                 0           NaN             any                   NaN
#
#       SecondCenterFrequency        Authentication   Security
# 3751                    NaN                   PSK       CCMP
# 3752                    NaN           IEEE 802.1X       CCMP
# 3753                    NaN           IEEE 802.1X       CCMP
# 3754                    0.0           IEEE 802.1X       CCMP
# 3755                    NaN                   NaN        NaN
# 3756                    0.0                   NaN        NaN
# 3757                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3758                    0.0                   NaN        NaN
# 3759                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3760                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3761                    NaN                   NaN        NaN
# 3762                    0.0                   NaN        NaN
# 3763                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3764                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3765                    NaN                   NaN        NaN
# 3766                    0.0                   NaN        NaN
# 3767                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3768                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3769                    NaN                   NaN        NaN
# 3770                    0.0                   NaN        NaN
# 3771                    0.0                   NaN        NaN
# 3772                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3773                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3774                    NaN                   NaN        NaN
# 3775                    0.0                   NaN        NaN
# 3776                    0.0                   NaN        NaN
# 3777                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3778                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3779                    NaN                   NaN        NaN
# 3780                    0.0                   NaN        NaN
# 3781                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3782                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3783                    NaN                   NaN        NaN
# 3784                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3785                    NaN                   NaN        NaN
# 3786                    0.0                   NaN        NaN
# 3787                    0.0  IEEE 802.1X FT/IEEE        CCMP
# 3788                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3789                    NaN                   NaN        NaN
# 3790                    NaN  IEEE 802.1X FT/IEEE        CCMP
# 3791                    NaN                   NaN        NaN
# 3792                    0.0                   PSK       CCMP
# 3793                    NaN                   NaN        NaN
# 3794                    NaN                   NaN        NaN
# 3795                    NaN                   NaN        NaN
# 3796                    NaN                   PSK  CCMP TKIP
# 3797                    NaN                   PSK  TKIP CCMP

# %% [markdown]
# ## Tasks to do:
# 1. Create the graph showing all the nodes, color it with the channels they are connecting
# 2. Try to take input into the batches i.e all the channels which the network can see according to these batches make sure that the network is running in the optimum condition for all the nodes with the distance.
